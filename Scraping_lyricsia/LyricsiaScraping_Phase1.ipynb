# %% [markdown]
# # Webscraping Bollywood songs from 1947-2018

# %% [markdown]
# We'll be scraping https://www.lyricsia.com/

# %% [markdown]
# ## Phase 1

# %%
import requests
import bs4 as bs
import requests
import csv
import time

# %%
# Opening the csv file in write mode and adding a header
with open(r'lyricsia_phase1.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerow(['SNo', 'Songpage_URL', 'Movie'])

# %%
year_page_url = 'https://www.lyricsia.com/hindi-songs/'
root_url = 'https://www.lyricsia.com'

# %%
# %%time
rowcount = 0

# The category pages are ordered and range from 1947 to 2018
for year in range(1947, 2019):
    
    url = year_page_url + str(year)
    
    try:
        # Fetching the page
        source = requests.get(url)
        
        # Parsing the html
        webpage = bs.BeautifulSoup(source.content, features='html.parser') 
    
        listofsongs = []
        for index, row in enumerate(webpage.findAll('tr')):
            # The first row contains the header
            if index != 0:
                songurl = root_url + row.select('td')[1].a['href'].split(';')[0]
                moviename = row.select('td')[2].text
                rowcount += 1
                
                listofsongs.append([rowcount, songurl, moviename])
                
        # Opening the file in append mode and adding the data for the entire page i.e. each year
        with open(r'lyricsia_phase1.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerows(listofsongs)
            
        # Printing the progress
        print(f'Data Scraped for year: {year}')
    except Exception as e:
        print(e)
# Out:
# Data Scraped for year: 1947
# Data Scraped for year: 1948
# Data Scraped for year: 1949
# Data Scraped for year: 1950
# Data Scraped for year: 1951
# Data Scraped for year: 1952
# Data Scraped for year: 1953
# Data Scraped for year: 1954
# Data Scraped for year: 1955
# Data Scraped for year: 1956
# Data Scraped for year: 1957
# Data Scraped for year: 1958
# Data Scraped for year: 1959
# Data Scraped for year: 1960
# Data Scraped for year: 1961
# Data Scraped for year: 1962
# Data Scraped for year: 1963
# Data Scraped for year: 1964
# Data Scraped for year: 1965
# Data Scraped for year: 1966
# Data Scraped for year: 1967
# Data Scraped for year: 1968
# Data Scraped for year: 1969
# Data Scraped for year: 1970
# Data Scraped for year: 1971
# Data Scraped for year: 1972
# Data Scraped for year: 1973
# Data Scraped for year: 1974
# Data Scraped for year: 1975
# Data Scraped for year: 1976
# Data Scraped for year: 1977
# Data Scraped for year: 1978
# Data Scraped for year: 1979
# Data Scraped for year: 1980
# Data Scraped for year: 1981
# Data Scraped for year: 1982
# Data Scraped for year: 1983
# Data Scraped for year: 1984
# Data Scraped for year: 1985
# Data Scraped for year: 1986
# Data Scraped for year: 1987
# Data Scraped for year: 1988
# Data Scraped for year: 1989
# Data Scraped for year: 1990
# Data Scraped for year: 1991
# Data Scraped for year: 1992
# Data Scraped for year: 1993
# Data Scraped for year: 1994
# Data Scraped for year: 1995
# Data Scraped for year: 1996
# Data Scraped for year: 1997
# Data Scraped for year: 1998
# Data Scraped for year: 1999
# Data Scraped for year: 2000
# Data Scraped for year: 2001
# Data Scraped for year: 2002
# Data Scraped for year: 2003
# Data Scraped for year: 2004
# Data Scraped for year: 2005
# Data Scraped for year: 2006
# Data Scraped for year: 2007
# Data Scraped for year: 2008
# Data Scraped for year: 2009
# Data Scraped for year: 2010
# Data Scraped for year: 2011
# Data Scraped for year: 2012
# Data Scraped for year: 2013
# Data Scraped for year: 2014
# Data Scraped for year: 2015
# Data Scraped for year: 2016
# Data Scraped for year: 2017
# Data Scraped for year: 2018
# CPU times: user 7.42 s, sys: 142 ms, total: 7.56 s
# Wall time: 1min 53s

# %% [markdown]
# ## Phase 2

# %%
import requests
import bs4 as bs
import requests
import csv
import time
import pandas as pd

# %%
# Opening the data scraped in phase 1
df = pd.read_csv('lyricsia_phase1.csv')

# %%
df.head()
# Out:
#    SNo                                       Songpage_URL          Movie
# 0    1  https://www.lyricsia.com/lyricid/5902/yahaan-b...          Jugnu
# 1    2  https://www.lyricsia.com/lyricid/5098/chand-si...           Elan
# 2    3  https://www.lyricsia.com/lyricid/5050/wo-apani...          Jugnu
# 3    4  https://www.lyricsia.com/lyricid/5048/yahan-ba...          Jugnu
# 4    5  https://www.lyricsia.com/lyricid/5082/khayegi-...  Mirza Sahiban

# %%
tableheaders = ['Song', 'Lyrics', 'Movie', 'Year', 'Singer', 'Writer', 'Composer']

# %%
# Creating a new file by opening it in write mode
with open(r'lyricsia_phase2.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerow(tableheaders)

# %%
# %%time

# Each row item contains the link to a song page
for i in range(len(df)):
    # Extracting the song page url from the row item
    songurl = df['Songpage_URL'][i]
    try:      
        
        # Getting the song page and parsing the html
        source = requests.get(songurl)
        webpage = bs.BeautifulSoup(source.content, features='html.parser') 

        # Finding various information about the song from the html 
        song = webpage.find('h1').text.split('Lyrics')[0]
        
        lyrics = webpage.find('pre').text
        
        metacontainer = webpage.find('div', attrs={'class':'col-sm-4 col-md-4'})
        
        movie = metacontainer.select('p')[1].text.split(':')[1].lstrip()
        singer = metacontainer.select('p')[2].text.split(':')[1].lstrip()
        writer = metacontainer.select('p')[3].text.split(':')[1].lstrip()
        composer = metacontainer.select('p')[4].text.split(':')[1].lstrip()
        year = metacontainer.select('p')[7].text.split(':')[1].lstrip()
        
        songdata = [song, lyrics, movie, year, singer, writer, composer]
        
        # Writing each row of song with its lyrics to csv file
        # Note that the file was opened in append mode
        with open(r'lyricsia_phase2.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerow(songdata)
            
        # Printing progress
        print(f'Added song {i+1}/{len(df)}: {song}')
        
    except Exception as e:
        print(e)
# Out:
# Added song 7045/7363: Piya Reprise
# Added song 7046/7363: Talli Hogiya
# Added song 7047/7363: Tu Chale Toh
# Added song 7048/7363: Yeh mera man
# Added song 7049/7363: Aaj Mile Hain
# Added song 7050/7363: Badass Babuaa
# Added song 7051/7363: Body Language
# Added song 7052/7363: Chete Karda 2
# Added song 7053/7363: I’ll Miss You
# Added song 7054/7363: Kudi Baeymaan
# Added song 7055/7363: Majaa Ni Life
# Added song 7056/7363: Nagada Nagada
# Added song 7057/7363: Party Nonstop
# Added song 7058/7363: Saajan Saajan
# Added song 7059/7363: Sardi Ki Raat
# Added song 7060/7363: Tere Jaane Se
# Added song 7061/7363: Trippy Trippy
# Added song 7062/7363: Tum Mere Baad
# Added song 7063/7363: Abhagi Piya Ki
# Added song 7064/7363: Ae Kash Ke Hum
# Added song 7065/7363: Dekhte Hi Fida
# Added song 7066/7363: Ik Yaad Purani
# Added song 7067/7363: Jahan Bhi Yaad
# Added song 7068/7363: Jatt Te Jawani
# Added song 7069/7363: Main Faraar Sa
# Added song 7070/7363: Naag The Third
# Added song 7071/7363: Pop The Bottle
# Added song 7072/7363: Rocket Saiyyan
# Added song 7073/7363: Taarashta Main
# Added song 7074/7363: Teri Razamandi
# Added song 7075/7363: Thodi Si Jagah
# Added song 7076/7363: Tum Hardafa Ho
# Added song 7077/7363: Twist Kamariya
# Added song 7078/7363: Balma Yeh Karma
# Added song 7079/7363: Feel The Rhythm
# Added song 7080/7363: Jaha Tum Rahoge
# Added song 7081/7363: Khamakha Yun Hi
# Added song 7082/7363: One Bottle Down
# Added song 7083/7363: President Roley
# Added song 7084/7363: Tere Naal Jeena
# Added song 7085/7363: The Goggle Song
# Added song 7086/7363: Twinkle Twinkle
# Added song 7087/7363: Yahin Hoon Main
# Added song 7088/7363: Barish Ki Boonde
# Added song 7089/7363: Beat it Bijuriya
# Added song 7090/7363: Blouse Ka Button
# Added song 7091/7363: Gallan Tipsiyaan
# Added song 7092/7363: Jaa Chhipkali Ja
# Added song 7093/7363: Mannerless Majnu
# Added song 7094/7363: Meri Pyaari Ammi
# Added song 7095/7363: Sajna Sohne Jiha
# Added song 7096/7363: Tu Pyar Hai Mera
# Added song 7097/7363: Tujhe Namaami Ho
# Added song 7098/7363: Yeh Jo Pyaar Hai
# Added song 7099/7363: Aaja Meri Bike Pe
# Added song 7100/7363: Band Vyah Da Baje
# Added song 7101/7363: Boyfriend Replace
# Added song 7102/7363: Cricket Wali Beat
# Added song 7103/7363: Dum Maro Dum Maro
# Added song 7104/7363: Hadh (Title) Song
# Added song 7105/7363: Mera Highway Star
# Added song 7106/7363: Oye Hoye Oye Hoye
# Added song 7107/7363: Rang Tere Pyar Ka
# Added song 7108/7363: Simran Title Song
# Added song 7109/7363: Thoddi Waala Till
# Added song 7110/7363: Will You Marry Me
# Added song 7111/7363: Yeh Hai Dance Bar
# Added song 7112/7363: Zindagi Yun Guzar
# Added song 7113/7363: Angreji Wali Madam
# Added song 7114/7363: Choorhey Wali Bahh
# Added song 7115/7363: Dhadkane Azad Hain
# Added song 7116/7363: Dil Jo Na Keh Saka
# Added song 7117/7363: Humsafar (Zaalima)
# Added song 7118/7363: Jai Baba Bank Chor
# Added song 7119/7363: Muhabbat Ko Misuse
# Added song 7120/7363: Sahiba Russ Gayiya
# Added song 7121/7363: Tere Wargi Nai Ae
# Added song 7122/7363: Teri Bhen Di Kurti
# Added song 7123/7363: Tu Hai Mera Sunday
# Added song 7124/7363: Yaad Hai Ya Bhulte
# Added song 7125/7363: Dhadkan (Unplugged)
# Added song 7126/7363: Don’t Hold Back 2.0
# Added song 7127/7363: Hum Tujhse Mohabbat
# Added song 7128/7363: Jahan Bhi Yaad Teri
# Added song 7129/7363: Khuda Tu Yeh Sun Le
# Added song 7130/7363: Khushi Waali Khushi
# Added song 7131/7363: Raat Abhi Baaki Hai
# Added song 7132/7363: Seene Mein Lagi Aag
# Added song 7133/7363: Tera Ishq Jee Paaun
# Added song 7134/7363: Trip Abhi Baaki Hai
# Added song 7135/7363: Ye Waqt Maut Ka Hai
# Added song 7136/7363: Chand Mera Naraz Hai
# Added song 7137/7363: Ek Dafaa (Chinnamma)
# Added song 7138/7363: Kaise Mujhe - Tum Ho
# Added song 7139/7363: Teri Khushi Tera Gam
# Added song 7140/7363: Har Mod Par Umeed Hai
# Added song 7141/7363: Itna Sannata Kyun Hai
# Added song 7142/7363: Naughty Naughty Party
# Added song 7143/7363: Soch Na Sake Sab Tera
# Added song 7144/7363: Hua Hai Aaj Pehli Baar
# Added song 7145/7363: Khwabon Ko Ankhon Mein
# Added song 7146/7363: Main Jo Dekhu Na Tujhe
# Added song 7147/7363: Nayan Ne Bandh Rakhine
# Added song 7148/7363: Pee Loon Ishq Sufiyana
# Added song 7149/7363: Aate Jaate Hanste Gaate
# Added song 7150/7363: Bae, Baba Aur Bank Chor
# Added song 7151/7363: Bechain Hu (Title Song)
# Added song 7152/7363: Desi Girls Do It Better
# Added song 7153/7363: Haathon Mein Thhe Haath
# Added song 7154/7363: Hawaon Mein Woh Aag Hai
# Added song 7155/7363: Londono Patola Reloaded
# Added song 7156/7363: Dil Dhadke Louder Louder
# Added song 7157/7363: Haan Haan Hum Peete Hain
# Added song 7158/7363: Roke Na Ruke - Mast Magan
# Added song 7159/7363: Sun Zara Tujhe Bhula Diya
# Added song 7160/7363: Agar Tum Saath Ho Maahi Ve
# Added song 7161/7363: Ishq Ne Aisa Shunk Baja Ya
# Added song 7162/7363: Kyun Gaye Tum (Title Song)
# Added song 7163/7363: Love U Family (Title) Song
# Added song 7164/7363: Ehna Akhiyan Yaar Mangiyasi
# Added song 7165/7363: Jattan Da Putt Mada Ho Gaya
# Added song 7166/7363: Na Lena Na Dena Magan Rahna
# Added song 7167/7363: Paas Baitho Na (Title) Song
# Added song 7168/7363: Hug Me Raghav Sachar Version
# Added song 7169/7363: Jal Jal Jal Rahi Hain Raatein
# Added song 7170/7363: Gazab Ka Hai Din – Bawara Mann
# Added song 7171/7363: Zindagi Tujhse Kya Karen Shikve
# Added song 7172/7363: Kala Chashma (Unplugged Version)
# Added song 7173/7363: Aankh Band Karke Logon Ki Na Sunke
# Added song 7174/7363: Tu Lagti Hai Ek Pyari Si Nanhi Pari
# Added song 7175/7363: Hulchul
# Added song 7176/7363: Gold Digger
# Added song 7177/7363: Aaj Likhenge Kal
# Added song 7178/7363: Main Agar Kahoon – Bol Do Na Zara
# Added song 7179/7363: Sooraj Dooba Hain – Subha Hone Na De
# Added song 7180/7363: Ghoomar
# Added song 7181/7363: Dil Chori
# Added song 7182/7363: Aaj Se Teri
# Added song 7183/7363: Bom Diggy Diggy
# Added song 7184/7363: Chhote Chhote Peg Maar
# Added song 7185/7363: Tere Bina
# Added song 7186/7363: Dilbar
# Added song 7187/7363: Mechanical Sundariye
# Added song 7188/7363: Nachle Na
# Added song 7189/7363: O Saathi
# Added song 7190/7363: Subah Subah
# Added song 7191/7363: Yaara
# Added song 7192/7363: Nazar Na Lag Jaaye
# Added song 7193/7363: Chogada
# Added song 7194/7363: Kuch Iss Tarah
# Added song 7195/7363: Ek Dil Ek Jaan
# Added song 7196/7363: Rakshassi
# Added song 7197/7363: Binte Dil
# Added song 7198/7363: Chad Gayi Hai
# Added song 7199/7363: Lo Safar
# Added song 7200/7363: Khalibali
# Added song 7201/7363: Paniyon Sa
# Added song 7202/7363: Aashiq Banaya Aapne
# Added song 7203/7363: Lakk Mera Hit
# Added song 7204/7363: Jitni Dafa
# Added song 7205/7363: Aanewale Kal
# Added song 7206/7363: Nainowale Ne
# Added song 7207/7363: Tera Fitoor
# Added song 7208/7363: Tera Yaar Hoon Main
# Added song 7209/7363: Selfish
# Added song 7210/7363: Thare Vaaste
# Added song 7211/7363: Sunn Le Zara
# Added song 7212/7363: Dekhte Dekhte
# Added song 7213/7363: Kaun Nachdi
# Added song 7214/7363: Oye Hichki
# Added song 7215/7363: Kya Kahoon Jaaneman
# Added song 7216/7363: Gazab Ka Hai Din
# Added song 7217/7363: Pant Mein Gun
# Added song 7218/7363: Sayaani
# Added song 7219/7363: Rozana
# Added song 7220/7363: Tajdar E Haram
# Added song 7221/7363: Achche Din
# Added song 7222/7363: Saale Sapne
# Added song 7223/7363: Gold Tamba
# Added song 7224/7363: Tere Jaisa Tu Hai
# Added song 7225/7363: Ye Dil Jo Hai Badmaash Hai
# Added song 7226/7363: Tareefan
# Added song 7227/7363: Nit Khair Manga
# Added song 7228/7363: Soniye Dil Nayi
# Added song 7229/7363: Rasta Rasta
# Added song 7230/7363: Mumma Ki Parchai
# Added song 7231/7363: Heeriye
# Added song 7232/7363: Sweety Slowly Slowly
# Added song 7233/7363: Paintra
# Added song 7234/7363: Tujhse Kahan Juda Hoon Main
# Added song 7235/7363: Ghar Layenge Gold
# Added song 7236/7363: De De Jagah
# Added song 7237/7363: High Rated Gabru
# Added song 7238/7363: Bandeya
# Added song 7239/7363: Get Ready To Fight Again
# Added song 7240/7363: Jaaga Hindustan
# Added song 7241/7363: Sacchi Mohabbat
# Added song 7242/7363: Mundiyan
# Added song 7243/7363: Naino Ne Baandhi
# Added song 7244/7363: Baba Theme
# Added song 7245/7363: Daryaa
# Added song 7246/7363: Kesariya Jugni
# Added song 7247/7363: Beat Junglee
# Added song 7248/7363: This Party is Over Now
# Added song 7249/7363: Aa Jao Na
# Added song 7250/7363: Maine Socha Ke Chura Loon
# Added song 7251/7363: Ek Do Teen
# Added song 7252/7363: Chal
# Added song 7253/7363: Dil Warda
# Added song 7254/7363: Khel Khel Mein
# Added song 7255/7363: Grey Walaa Shade
# Added song 7256/7363: Mehbooba
# Added song 7257/7363: Rabb Jane
# Added song 7258/7363: Zingaat
# Added song 7259/7363: Khudara
# Added song 7260/7363: Angelina
# Added song 7261/7363: Kar Har Maidaan Fateh
# Added song 7262/7363: Phir Se (Title Track)
# Added song 7263/7363: Tere Naal Nachna
# Added song 7264/7363: Nain Phisal Gaye
# Added song 7265/7363: Chota Sa Fasana
# Added song 7266/7363: Dilbaro
# Added song 7267/7363: Bhopu Baj Raha Hai
# Added song 7268/7363: Kamariya
# Added song 7269/7363: Pappi Le Loon
# Added song 7270/7363: Dhadak (Title)
# Added song 7271/7363: Hu Ba Hu
# Added song 7272/7363: Flicker Singh
# Added song 7273/7363: Kangan
# Added song 7274/7363: Pehli Baar
# Added song 7275/7363: Bewafa Beauty
# Added song 7276/7363: Happy Happy
# Added song 7277/7363: Swagpur Ka Chaudhary
# Added song 7278/7363: Shubh Din
# Added song 7279/7363: Ishtehaar
# Added song 7280/7363: Nazarbattu
# Added song 7281/7363: Heer
# Added song 7282/7363: Bass Gira De Raja
# Added song 7283/7363: Tu Meri Main Tera
# Added song 7284/7363: Dagmag Dagmag
# Added song 7285/7363: Halka Halka
# Added song 7286/7363: High End
# Added song 7287/7363: Tere Thumke Sapna Choudhary
# Added song 7288/7363: Mohabbat
# Added song 7289/7363: Fu Bai Fu
# Added song 7290/7363: Tab Bhi Tu
# Added song 7291/7363: Gaadi
# Added song 7292/7363: Monobina
# Added song 7293/7363: Shuru Kar
# Added song 7294/7363: Good Man Di Laaltain
# Added song 7295/7363: Little Little
# Added song 7296/7363: The Pad Man Title Song
# Added song 7297/7363: Mind Blowing
# Added song 7298/7363: O Meri Laila
# Added song 7299/7363: Ishq Di Baajiyaan
# Added song 7300/7363: Swag Saha Nahi Jaye
# Added song 7301/7363: Bhangra Ta Sajda (No One Gives A Damn!)
# Added song 7302/7363: Allah Duhai Hai
# Added song 7303/7363: Barf Si
# Added song 7304/7363: Holi Biraj Ma
# Added song 7305/7363: Manwa
# Added song 7306/7363: Sapna
# Added song 7307/7363: Hatt Ja Tau
# Added song 7308/7363: Ae Watan
# Added song 7309/7363: Sanu Ek Pal Chain
# Added song 7310/7363: Thehar Ja
# Added song 7311/7363: Ruby Ruby
# Added song 7312/7363: Dil Ton Black
# Added song 7313/7363: Mujhe Chand Pe Le Chalo
# Added song 7314/7363: Happy Bhag Jayegi (Title Song)
# Added song 7315/7363: Raat Kitni
# Added song 7316/7363: Nakhra Nawabi
# Added song 7317/7363: Badan Pe Sitare
# Added song 7318/7363: Oh Humsafar
# Added song 7319/7363: Boond Boond
# Added song 7320/7363: Dil Meri Na Sune
# Added song 7321/7363: Party Chale On
# Added song 7322/7363: Saiyan Re
# Added song 7323/7363: Kasumbi
# Added song 7324/7363: Pyar Le Pyar De
# Added song 7325/7363: Naam Hai Mera
# Added song 7326/7363: Chin Chin Chu
# Added song 7327/7363: Harjai
# Added song 7328/7363: Kudiye Ni Tere
# Added song 7329/7363: Soorma Anthem
# Added song 7330/7363: Baba Bolta Hai Bas Ho Gaya
# Added song 7331/7363: Milegi Milegi
# Added song 7332/7363: Koi Gal Nai
# Added song 7333/7363: Main Badhiya Tu Bhi Badhiya
# Added song 7334/7363: F for Fyaar
# Added song 7335/7363: Black
# Added song 7336/7363: Mohabbat Nasha Hai
# Added song 7337/7363: Lae Dooba
# Added song 7338/7363: Tum Mere Ho
# Added song 7339/7363: Piya Samaye
# Added song 7340/7363: Nindaraan Diyaan
# Added song 7341/7363: Galla Goriyan
# Added song 7342/7363: Veere
# Added song 7343/7363: Sehmi Hai Dhadkan
# Added song 7344/7363: Raazi (Title)
# Added song 7345/7363: Badnaamiyan
# Added song 7346/7363: Bachche Ki Jaan
# Added song 7347/7363: Badla
# Added song 7348/7363: Yaad Hai
# Added song 7349/7363: Jhuk Na Paunga
# Added song 7350/7363: Pardesiya
# Added song 7351/7363: Thenge Se
# Added song 7352/7363: Sataasat
# Added song 7353/7363: Hallaa
# Added song 7354/7363: Patola
# Added song 7355/7363: Mummy Kasam
# Added song 7356/7363: Chonch Ladhiyaan
# Added song 7357/7363: Chan Kitthan
# Added song 7358/7363: Aahista
# Added song 7359/7363: Laaj Sharam
# Added song 7360/7363: Vaara Re
# Added song 7361/7363: Mushkil Hai Apna Meil Priye
# Added song 7362/7363: Bas Tu Hai
# Added song 7363/7363: Paltan (Title Song)
# CPU times: user 29.6 s, sys: 554 ms, total: 30.1 s
# Wall time: 8min 35s
